# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/phonchi/CryoParticleSegment/blob/main/notebook/04_particle_extraction_clean.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
# </table>

# %% [markdown]
# ### CryoParticleSegment

# %%
# %pip install torchinfo -qq
# %pip install -U git+https://github.com/qubvel/segmentation_models.pytorch -qq
# %pip install starfile -qq
# %pip install https://github.com/soft-matter/trackpy/archive/master.zip -qq
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 121.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 96.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 60.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 40.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 18.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 110.9 MB/s eta 0:00:00
#   Building wheel for segmentation_models_pytorch (pyproject.toml) ... done
#      - 10.7 MB 10.0 MB/s 0:00:01
#   Preparing metadata (setup.py) ... done
#   Building wheel for trackpy (setup.py) ... done

# %% [markdown]
# > #### ⚠ Notice
# >
# > You need to restart the kernel after the following step.

# %%
# %pip install pycuda==2024.1
# %pip install "numpy<2.0"
# %pip install mrcfile -qq
# Out:
# Collecting pycuda==2024.1
#   Downloading pycuda-2024.1.tar.gz (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 74.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pytools>=2011.2 (from pycuda==2024.1)
#   Downloading pytools-2025.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting appdirs>=1.4.0 (from pycuda==2024.1)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: mako in /usr/lib/python3/dist-packages (from pycuda==2024.1) (1.1.3)
# Requirement already satisfied: platformdirs>=2.2 in /usr/local/lib/python3.11/dist-packages (from pytools>=2011.2->pycuda==2024.1) (4.3.8)
# Collecting siphash24>=1.6 (from pytools>=2011.2->pycuda==2024.1)
#   Downloading siphash24-1.7-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.3 kB)
# Requirement already satisfied: typing-extensions>=4.5 in /usr/local/lib/python3.11/dist-packages (from pytools>=2011.2->pycuda==2024.1) (4.14.0)
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Downloading pytools-2025.1.6-py3-none-any.whl (95 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.0/96.0 kB 10.5 MB/s eta 0:00:00
# Downloading siphash24-1.7-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (105 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.6/105.6 kB 12.2 MB/s eta 0:00:00
# Building wheels for collected packages: pycuda
#   Building wheel for pycuda (pyproject.toml) ... done
#   Created wheel for pycuda: filename=pycuda-2024.1-cp311-cp311-linux_x86_64.whl size=659519 sha256=07da3bbbc045b805626c6a74439cea5d08011ac718873c3e1d904b0a6274259f
#   Stored in directory: /root/.cache/pip/wheels/9f/8c/1d/f9e11f5c0a8f91fd93b22ebf74c364ec59bc28bb2f76b2f64d
# Successfully built pycuda
# Installing collected packages: appdirs, siphash24, pytools, pycuda
# Successfully installed appdirs-1.4.4 pycuda-2024.1 pytools-2025.1.6 siphash24-1.7
# Collecting numpy<2.0
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 5.2 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 95.7 MB/s eta 0:00:00
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed numpy-1.26.4
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.0/45.0 kB 4.0 MB/s eta 0:00:00
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/cli/base_command.py", line 179, in exc_logging_wrapper
#     status = run_func(*args)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/cli/req_command.py", line 67, in wrapper
# ^C

# %% [markdown]
# ## ⭐ Setup
# You must run all codes under this category.

# %% [markdown]
# ### ✅ Directory Settings

# %%
# @title  { display-mode: "form" }

IMAGE_DIR = "/content/drive/MyDrive/research_xc/dataset/10017/processed_micrographs_np_split" # @param {type:"string"}
LABEL_DIR = "/content/drive/MyDrive/research_xc/dataset/10017/micrographs_ground_np" # @param {type:"string"}
DATASET_DIR = "/content/drive/MyDrive/research_xc/dataset" # @param {type:"string"}
RESULT_DIR = "/content/drive/MyDrive/research_xc/results/10017_test/unet_eb5_dice_CDCRF" # @param {type:"string"}

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# @title  { display-mode: "form" }
# @markdown Detect whether using folder in Google Drive as **`RESULT DIR`**📁.
import os
if "content" in IMAGE_DIR.split("/")[:3] or "content" in LABEL_DIR.split("/")[:3]:
  try:
    from google.colab import drive
    drive.mount('/content/drive')
    # !rm -r /content/sample_data
    if not os.path.exists("/content/image_dir"):
        if "content" in IMAGE_DIR.split("/")[:3]:
            # !cp -r {IMAGE_DIR} /content/image_dir
            IMAGE_DIR = "/content/image_dir"
        if "content" in LABEL_DIR.split("/")[:3]:
            # !cp -r {LABEL_DIR} /content/label_dir
            LABEL_DIR = "/content/label_dir"
  except:
    pass
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# rm: cannot remove '/content/sample_data': No such file or directory

# %%
IMAGE_DIR = "/content/image_dir"

# %%
# !git clone https://github.com/phonchi/CryoParticleSegment.git
# Out:
# Cloning into 'CryoParticleSegment'...
# remote: Enumerating objects: 195, done.
# remote: Counting objects: 100% (195/195), done.
# remote: Compressing objects: 100% (185/185), done.
# remote: Total 195 (delta 90), reused 27 (delta 6), pack-reused 0 (from 0)
# Receiving objects: 100% (195/195), 29.46 MiB | 12.55 MiB/s, done.
# Resolving deltas: 100% (90/90), done.

# %%
import sys
import os

# Adjust the path relative to your current working directory
module_path = os.path.abspath('CryoParticleSegment/Modeling')

# Add to sys.path if it's not already included
if module_path not in sys.path:
    sys.path.append(module_path)

# %% [markdown]
# > #### ⚠ Notice
# >
# > You need to restart the kernel after the compilation step. Additionally, if your GPU architecture differs, you may need to modify the file at `/content/CryoParticleSegment/Modeling/CRF_main/setup.py`. (We attempt to detect the GPU configuration automatically, so this step is usually not necessary.)
# > Furthermore, depending on the number of classes and other parameters, you may encounter an error that requires adjusting the file at `/content/CryoParticleSegment/Modeling/CRF_main/src/PermutohedralFiltering/source/gpu/LatticeFilter.cu`:
# >
# > 1. Note the `pd` and `vd` values from the error message.
# > 2. Add an `else if (pd == ? && vd == ?)` block.
# > 3. Within that block, insert the following line, replacing `pd` and `vd` with the specific values:
# >
# >    ```cpp
# >    latticeFilterGPU<pd, vd>(output_tensor, input_tensor, positions, num_super_pixels, backward);
# >    ```
# > 4. Recompile using `setup.py`.

# %%
#%git clone https://github.com/netw0rkf10w/CRF.git
# %cd CryoParticleSegment/Modeling/CRF_main
# !python setup.py clean --all
# !rm -rf build/
# !python setup.py build_ext --inplace --force
# !python setup.py install
# Out:
# /content/CryoParticleSegment/Modeling/CRF_main
# running clean
# 'build/lib.linux-x86_64-cpython-311' does not exist -- can't clean it
# 'build/bdist.linux-x86_64' does not exist -- can't clean it
# 'build/scripts-3.11' does not exist -- can't clean it
# running build_ext
# /usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py:529: UserWarning: Attempted to use ninja as the BuildExtension backend but we could not find ninja.. Falling back to using the slow distutils backend.
#   warnings.warn(msg.format('we could not find ninja.'))
# /usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py:448: UserWarning: The detected CUDA version (12.5) has a minor version mismatch with the version that was used to compile PyTorch (12.4). Most likely this shouldn't be a problem.
#   warnings.warn(CUDA_MISMATCH_WARN.format(cuda_str_version, torch.version.cuda))
# /usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py:458: UserWarning: There are no x86_64-linux-gnu-g++ version bounds defined for CUDA version 12.5
#   warnings.warn(f'There are no {compiler_name} version bounds defined for CUDA version {cuda_str_version}')
# building 'Permutohedral' extension
# creating build/temp.linux-x86_64-cpython-311/src/PermutohedralFiltering/source/cpu
# x86_64-linux-gnu-g++ -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -I/usr/local/lib/python3.11/dist-packages/torch/include -I/usr/local/lib/python3.11/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.11/dist-packages/torch/include/TH -I/usr/local/lib/python3.11/dist-packages/torch/include/THC -I/usr/include/python3.11 -c src/PermutohedralFiltering/source/cpu/LatticeFilterKernel.cpp -o build/temp.linux-x86_64-cpython-311/src/PermutohedralFiltering/source/cpu/LatticeFilterKernel.o -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE=\"_gcc\" -DPYBIND11_STDLIB=\"_libstdcpp\" -DPYBIND11_BUILD_ABI=\"_cxxabi1011\" -DTORCH_EXTENSION_NAME=Permutohedral -D_GLIBCXX_USE_CXX11_ABI=0 -std=c++17
# src/PermutohedralFiltering/source/cpu/LatticeFilterKernel.cpp: In function ‘at::Tensor LatticeFilter_calculate(const at::Tensor&, const at::Tensor&, bool, float, float, float, bool)’:
# src/PermutohedralFiltering/source/cpu/LatticeFilterKernel.cpp:77:97: warning: ‘at::DeprecatedTypeProperties& at::Tensor::type() const’ is deprecated: Tensor.type() is deprecated. Instead use Tensor.options(), which in many cases (e.g. in a constructor) is a drop-in replacement. If you were using data from type(), that is now available from Tensor itself, so instead of tensor.type().scalar_type(), use tensor.scalar_type() instead and instead of tensor.type().backend() use tensor.device(). [-Wdeprecated-declarations]
#    77 |         at::Tensor positions = at::zeros({batch_size * num_super_pixels * pd}, input_tensor.type() );
#       |                                                                                ~~~~~~~~~~~~~~~~~^~
# In file included from /usr/local/lib/python3.11/dist-packages/torch/include/ATen/core/Tensor.h:3,
#                  from /usr/local/lib/python3.11/dist-packages/torch/include/ATen/Tensor.h:3,
#                  from /usr/local/lib/python3.11/dist-packages/torch/include/torch/csrc/autograd/function_hook.h:3,
#                  from /usr/local/lib/python3.11/dist-packages/torch/include/torch/csrc/autograd/cpp_hook.h:2,
#                  from /usr/local/lib/python3.11/dist-packages/torch/include/torch/csrc/autograd/variable.h:6,
#                  from /usr/local/lib/python3.11/dist-packages/torch/include/torch/csrc/autograd/autograd.h:3,
#                  from /usr/local/lib/python3.11/dist-packages/torch/include/torch/csrc/api/include/torch/autograd.h:3,
#                  from /usr/local/lib/python3.11/dist-packages/torch/include/torch/csrc/api/include/torch/all.h:7,
#                  from /usr/local/lib/python3.11/dist-packages/torch/include/torch/extension.h:5,
#                  from src/PermutohedralFiltering/source/cpu/LatticeFilterKernel.cpp:25:
# /usr/local/lib/python3.11/dist-packages/torch/include/ATen/core/TensorBody.h:225:30: note: declared here
#   225 |   DeprecatedTypeProperties & type() const {
#       |                              ^~~~
# creating build/lib.linux-x86_64-cpython-311
# x86_64-linux-gnu-g++ -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -shared -Wl,-O1 -Wl,-Bsymbolic-functions build/temp.linux-x86_64-cpython-311/src/PermutohedralFiltering/source/cpu/LatticeFilterKernel.o -L/usr/local/lib/python3.11/dist-packages/torch/lib -L/usr/lib/x86_64-linux-gnu -lc10 -ltorch -ltorch_cpu -ltorch_python -o build/lib.linux-x86_64-cpython-311/Permutohedral.cpython-311-x86_64-linux-gnu.so
# building 'Permutohedral_gpu' extension
# creating build/temp.linux-x86_64-cpython-311/src/PermutohedralFiltering/source/gpu
# /usr/local/cuda/bin/nvcc -I/usr/local/lib/python3.11/dist-packages/torch/include -I/usr/local/lib/python3.11/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.11/dist-packages/torch/include/TH -I/usr/local/lib/python3.11/dist-packages/torch/include/THC -I/usr/local/cuda/include -I/usr/include/python3.11 -c src/PermutohedralFiltering/source/gpu/LatticeFilter.cu -o build/temp.linux-x86_64-cpython-311/src/PermutohedralFiltering/source/gpu/LatticeFilter.o -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_BFLOAT16_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ --expt-relaxed-constexpr --compiler-options '-fPIC' -gencode=arch=compute_89,code=sm_89 -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE=\"_gcc\" -DPYBIND11_STDLIB=\"_libstdcpp\" -DPYBIND11_BUILD_ABI=\"_cxxabi1011\" -DTORCH_EXTENSION_NAME=Permutohedral_gpu -D_GLIBCXX_USE_CXX11_ABI=0 -std=c++17
# src/PermutohedralFiltering/source/gpu/LatticeFilter.cu: In function ‘at::Tensor LatticeFilter_calculate_gpu(const at::Tensor&, const at::Tensor&, bool, float, float, float, bool, bool)’:
# src/PermutohedralFiltering/source/gpu/LatticeFilter.cu:202:91: warning: ‘at::DeprecatedTypeProperties& at::Tensor::type() const’ is deprecated: Tensor.type() is deprecated. Instead use Tensor.options(), which in many cases (e.g. in a constructor) is a drop-in replacement. If you were using data from type(), that is now available from Tensor itself, so instead of tensor.type().scalar_type(), use tensor.scalar_type() instead and instead of tensor.type().backend() use tensor.device(). [-Wdeprecated-declarations]
#   202 |     at::Tensor positions = at::zeros(
#       |                                                                                           ^
# /usr/local/lib/python3.11/dist-packages/torch/include/ATen/core/TensorBody.h:225:1: note: declared here
#   225 |   DeprecatedTypeProperties & type() const {
#       | ^ ~~
# src/PermutohedralFiltering/source/gpu/LatticeFilter.cu:208:67: warning: ‘at::DeprecatedTypeProperties& at::Tensor::type() const’ is deprecated: Tensor.type() is deprecated. Instead use Tensor.options(), which in many cases (e.g. in a constructor) is a drop-in replacement. If you were using data from type(), that is now available from Tensor itself, so instead of tensor.type().scalar_type(), use tensor.scalar_type() instead and instead of tensor.type().backend() use tensor.device(). [-Wdeprecated-declarations]
#   208 |     CHECK_INPUT(image_tensor);
#       |                                                                   ^
# /usr/local/lib/python3.11/dist-packages/torch/include/ATen/core/TensorBody.h:225:1: note: declared here
#   225 |   DeprecatedTypeProperties & type() const {
#       | ^ ~~
# src/PermutohedralFiltering/source/gpu/LatticeFilter.cu:209:64: warning: ‘at::DeprecatedTypeProperties& at::Tensor::type() const’ is deprecated: Tensor.type() is deprecated. Instead use Tensor.options(), which in many cases (e.g. in a constructor) is a drop-in replacement. If you were using data from type(), that is now available from Tensor itself, so instead of tensor.type().scalar_type(), use tensor.scalar_type() instead and instead of tensor.type().backend() use tensor.device(). [-Wdeprecated-declarations]
#   209 |     CHECK_INPUT(positions);
#       |                                                                ^
# /usr/local/lib/python3.11/dist-packages/torch/include/ATen/core/TensorBody.h:225:1: note: declared here
#   225 |   DeprecatedTypeProperties & type() const {
#       | ^ ~~
# src/PermutohedralFiltering/source/gpu/LatticeFilter.cu:213:44: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   213 |         auto ref_ptr = &(image_tensor.data<float>()[b * num_super_pixels * n_reference_channels]);
#       |                  ~~~~~~~~~~~~~~~~~~~~~~~~~~^~
# /usr/local/lib/python3.11/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# src/PermutohedralFiltering/source/gpu/LatticeFilter.cu:214:41: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   214 |         auto pos_ptr = &(positions.data<float>()[b * num_super_pixels * pd]);
#       |                  ~~~~~~~~~~~~~~~~~~~~~~~^~
# /usr/local/lib/python3.11/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# src/PermutohedralFiltering/source/gpu/LatticeFilter.cu:215:43: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   215 |         auto in_ptr = &(input_tensor.data<float>()[b * num_super_pixels * n_input_channels]);
#       |                 ~~~~~~~~~~~~~~~~~~~~~~~~~~^~
# /usr/local/lib/python3.11/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# src/PermutohedralFiltering/source/gpu/LatticeFilter.cu:216:45: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   216 |         auto out_ptr = &(output_tensor.data<float>()[b * num_super_pixels * n_input_channels]);
#       |                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~^~
# /usr/local/lib/python3.11/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# x86_64-linux-gnu-g++ -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -shared -Wl,-O1 -Wl,-Bsymbolic-functions build/temp.linux-x86_64-cpython-311/src/PermutohedralFiltering/source/gpu/LatticeFilter.o -L/usr/local/lib/python3.11/dist-packages/torch/lib -L/usr/local/cuda/lib64 -L/usr/lib/x86_64-linux-gnu -lc10 -ltorch -ltorch_cpu -ltorch_python -lcudart -lc10_cuda -ltorch_cuda -o build/lib.linux-x86_64-cpython-311/Permutohedral_gpu.cpython-311-x86_64-linux-gnu.so
# copying build/lib.linux-x86_64-cpython-311/Permutohedral.cpython-311-x86_64-linux-gnu.so -> src
# copying build/lib.linux-x86_64-cpython-311/Permutohedral_gpu.cpython-311-x86_64-linux-gnu.so -> src
# running install
# /usr/local/lib/python3.11/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# /usr/local/lib/python3.11/dist-packages/setuptools/_distutils/cmd.py:66: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://github.com/pypa/setuptools/issues/917 for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# running bdist_egg
# running egg_info
# creating src/CRF.egg-info
# writing src/CRF.egg-info/PKG-INFO
# writing dependency_links to src/CRF.egg-info/dependency_links.txt
# writing top-level names to src/CRF.egg-info/top_level.txt
# writing manifest file 'src/CRF.egg-info/SOURCES.txt'
# /usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py:529: UserWarning: Attempted to use ninja as the BuildExtension backend but we could not find ninja.. Falling back to using the slow distutils backend.
#   warnings.warn(msg.format('we could not find ninja.'))
# reading manifest file 'src/CRF.egg-info/SOURCES.txt'
# adding license file 'LICENSE'
# writing manifest file 'src/CRF.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build/lib.linux-x86_64-cpython-311/PermutohedralFiltering
# copying src/PermutohedralFiltering/PermutohedralFiltering.py -> build/lib.linux-x86_64-cpython-311/PermutohedralFiltering
# copying src/PermutohedralFiltering/__init__.py -> build/lib.linux-x86_64-cpython-311/PermutohedralFiltering
# copying src/PermutohedralFiltering/setup.py -> build/lib.linux-x86_64-cpython-311/PermutohedralFiltering
# creating build/lib.linux-x86_64-cpython-311/CRF
# copying src/CRF/crfs_cpu.py -> build/lib.linux-x86_64-cpython-311/CRF
# copying src/CRF/__init__.py -> build/lib.linux-x86_64-cpython-311/CRF
# copying src/CRF/convcrf.py -> build/lib.linux-x86_64-cpython-311/CRF
# copying src/CRF/CRF.py -> build/lib.linux-x86_64-cpython-311/CRF
# copying src/CRF/sparsemax.py -> build/lib.linux-x86_64-cpython-311/CRF
# running build_ext
# /usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py:448: UserWarning: The detected CUDA version (12.5) has a minor version mismatch with the version that was used to compile PyTorch (12.4). Most likely this shouldn't be a problem.
#   warnings.warn(CUDA_MISMATCH_WARN.format(cuda_str_version, torch.version.cuda))
# /usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py:458: UserWarning: There are no x86_64-linux-gnu-g++ version bounds defined for CUDA version 12.5
#   warnings.warn(f'There are no {compiler_name} version bounds defined for CUDA version {cuda_str_version}')
# creating build/bdist.linux-x86_64/egg
# copying build/lib.linux-x86_64-cpython-311/Permutohedral_gpu.cpython-311-x86_64-linux-gnu.so -> build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/PermutohedralFiltering
# copying build/lib.linux-x86_64-cpython-311/PermutohedralFiltering/PermutohedralFiltering.py -> build/bdist.linux-x86_64/egg/PermutohedralFiltering
# copying build/lib.linux-x86_64-cpython-311/PermutohedralFiltering/__init__.py -> build/bdist.linux-x86_64/egg/PermutohedralFiltering
# copying build/lib.linux-x86_64-cpython-311/PermutohedralFiltering/setup.py -> build/bdist.linux-x86_64/egg/PermutohedralFiltering
# copying build/lib.linux-x86_64-cpython-311/Permutohedral.cpython-311-x86_64-linux-gnu.so -> build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/CRF
# copying build/lib.linux-x86_64-cpython-311/CRF/crfs_cpu.py -> build/bdist.linux-x86_64/egg/CRF
# copying build/lib.linux-x86_64-cpython-311/CRF/__init__.py -> build/bdist.linux-x86_64/egg/CRF
# copying build/lib.linux-x86_64-cpython-311/CRF/convcrf.py -> build/bdist.linux-x86_64/egg/CRF
# copying build/lib.linux-x86_64-cpython-311/CRF/CRF.py -> build/bdist.linux-x86_64/egg/CRF
# copying build/lib.linux-x86_64-cpython-311/CRF/sparsemax.py -> build/bdist.linux-x86_64/egg/CRF
# byte-compiling build/bdist.linux-x86_64/egg/PermutohedralFiltering/PermutohedralFiltering.py to PermutohedralFiltering.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/PermutohedralFiltering/__init__.py to __init__.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/PermutohedralFiltering/setup.py to setup.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/CRF/crfs_cpu.py to crfs_cpu.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/CRF/__init__.py to __init__.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/CRF/convcrf.py to convcrf.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/CRF/CRF.py to CRF.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/CRF/sparsemax.py to sparsemax.cpython-311.pyc
# creating stub loader for Permutohedral.cpython-311-x86_64-linux-gnu.so
# creating stub loader for Permutohedral_gpu.cpython-311-x86_64-linux-gnu.so
# byte-compiling build/bdist.linux-x86_64/egg/Permutohedral.py to Permutohedral.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/Permutohedral_gpu.py to Permutohedral_gpu.cpython-311.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying src/CRF.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying src/CRF.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying src/CRF.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying src/CRF.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# writing build/bdist.linux-x86_64/egg/EGG-INFO/native_libs.txt
# zip_safe flag not set; analyzing archive contents...
# CRF.__pycache__.crfs_cpu.cpython-311: module references __file__
# __pycache__.Permutohedral.cpython-311: module references __file__
# __pycache__.Permutohedral_gpu.cpython-311: module references __file__
# creating dist
# creating 'dist/CRF-0.0.1-py3.11-linux-x86_64.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing CRF-0.0.1-py3.11-linux-x86_64.egg
# creating /usr/local/lib/python3.11/dist-packages/CRF-0.0.1-py3.11-linux-x86_64.egg
# Extracting CRF-0.0.1-py3.11-linux-x86_64.egg to /usr/local/lib/python3.11/dist-packages
# Adding CRF 0.0.1 to easy-install.pth file
#
# Installed /usr/local/lib/python3.11/dist-packages/CRF-0.0.1-py3.11-linux-x86_64.egg
# Processing dependencies for CRF==0.0.1
# Finished processing dependencies for CRF==0.0.1

# %%
# %cd /content/
# Out:
# /content

# %% [markdown]
# ### ✅ Packages Handling

# %%
# @title  { display-mode: "form" }
# @markdown Useful packages.

import os
import numpy as np
import matplotlib.pyplot as plt
import torch
from torch.utils.data import DataLoader
from torch.optim.lr_scheduler import ReduceLROnPlateau, OneCycleLR

# %%
# @title  { display-mode: "form" }
# @markdown User-defined packages.

from dataset import MicrographDataset, MicrographDatasetEvery
from dataset import reconstruct_patched
from model import create_model
from trainer import CryoEMEvaluator
from trainer import CryoEMTrainerWithScheduler, tqdm_plugin_for_Trainer

# %% [markdown]
# ## ⭐ Main

# %% [markdown]
# ### ✅ Setting

# %%
# @markdown Parameters.

NUM_CLASSES = 2
EPOCHS = 50
BATCH = 2
CROP_SIZE = (512, 512)
LR = 1e-3

RLR_PATIENCE = 3
ES_PATIENCE = 15
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# @markdown Set seed.

random_state = 42
torch.manual_seed(random_state)
torch.cuda.manual_seed_all(random_state)

# %% [markdown]
# ## ⭐ Convcrf wtih FCN finetuned on cryoem

# %% [markdown]
# ### ✅ Model

# %% [markdown]
# ## The model

# %%
# @title  { display-mode: "form" }

architecture = "Unet++" # @param {type:"string"}
encoder = "timm-efficientnet-b5" # @param {type:"string"}
pretrained = True # @param {type:"boolean"}
solver = "fw" # @param {type:"string"}
use_unary_only = True # @param {type:"boolean"}

# %%
import segmentation_models_pytorch as smp

if pretrained:
  weights = "imagenet"
else:
  weights = None

if architecture == "Unet++":
    backbone = smp.UnetPlusPlus(
        encoder_name=encoder,        # choose encoder, densenet201, resnet50, e.g. mobilenet_v2 or efficientnet-b5
        encoder_weights=weights,     # use `imagenet` or `advprop` for pre-trained weights for encoder initialization
        in_channels=1,                  # model input channels (1 for gray-scale images, 3 for RGB, etc.)
        classes=2,                      # model output channels (number of classes in your dataset)
    )

elif architecture == "Deeplab":
    backbone = smp.DeepLabV3(
        encoder_name=encoder,        # choose encoder, densenet201, resnet50, e.g. mobilenet_v2 or efficientnet-b5
        encoder_weights=weights,     # use `imagenet` pre-trained weights for encoder initialization
        in_channels=1,                  # model input channels (1 for gray-scale images, 3 for RGB, etc.)
        classes=2,                      # model output channels (number of classes in your dataset)
    )
else:
    print("Architecture not supported")
    raise NotImplementedError

model = create_model(backbone, addout=True) #crf_args

# %%
import CRF
import torch.nn as nn
from model import setup_crf, create_fwcrf_model

# Example usage
solver = 'fw'  # Assuming the solver type is defined

crf = setup_crf(solver, NUM_CLASSES)
model_post = create_fwcrf_model(model.backbone, crf, use_unary_only=True)
# Out:
# CRF solver: fw
# x0_weight: 0.0
# FrankWolfeParams:
# 	 scheme:	 fixed
# 	 stepsize:	 1.0 (for the 'fixed' scheme)
# 	 regularizer:	 l2
# 	 lambda_:	 1.0
# 	 lambda_learnable:	 False
# 	 x0_weight:	 0.5
# 	 x0_weight_learnable:	 False
# Non-trainable lambda for Frank-Wolfe: 1.0
# Non-trainable x0_weight for Frank-Wolfe: 0.5
# Potts: remove random weights.
# Add 1.0 to spatial_weight diagonal
# Add 1.0 to bilateral_weight diagonal
# Add -1.0 to compatibility diagonal

# %% [markdown]
# ## ⭐ Evaluate

# %%
import gc
gc.collect()
torch.cuda.empty_cache()

from torchvision.utils import save_image
from dataset import reconstruct_patched

def simple_micrograph_preprocessing(micrograph):
  micrograph_copy = micrograph.copy()
  micrograph_copy = (micrograph_copy-micrograph.mean()+2.5*micrograph.std())/5/micrograph.std()
  micrograph_copy[micrograph_copy<0]=0
  micrograph_copy[micrograph_copy>1]=1
  return micrograph_copy

# %%
from torch.utils.data import ConcatDataset

train_dir = os.path.join(IMAGE_DIR, 'train')
train_filenames = np.loadtxt(f"{IMAGE_DIR}/train_filenames.txt", dtype=str)
train_dataset =  MicrographDatasetEvery(image_dir=train_dir, label_dir=LABEL_DIR, filenames=train_filenames, crop_size=CROP_SIZE)
train_loader = DataLoader(train_dataset , batch_size=None, shuffle=False, pin_memory=True)

val_dir = os.path.join(IMAGE_DIR, 'val')
val_filenames = np.loadtxt(f"{IMAGE_DIR}/val_filenames.txt", dtype=str)
val_dataset = MicrographDatasetEvery(image_dir=val_dir, label_dir=LABEL_DIR, filenames=val_filenames, crop_size=CROP_SIZE)
val_loader = DataLoader(val_dataset, batch_size=None, shuffle=False, pin_memory=True)

test_dir = os.path.join(IMAGE_DIR, 'test')
test_filenames = np.loadtxt(f"{IMAGE_DIR}/test_filenames.txt", dtype=str)
test_dataset = MicrographDatasetEvery(image_dir=test_dir, label_dir=None, filenames=test_filenames, crop_size=CROP_SIZE)
test_loader = DataLoader(test_dataset, batch_size=None, shuffle=False, pin_memory=True)

full_filenames = np.concatenate((train_filenames, val_filenames, test_filenames))
full_dataset = ConcatDataset([train_dataset, val_dataset, test_dataset])
full_loader = DataLoader(full_dataset, batch_size=32, shuffle=True, pin_memory=True)

# %%
shape = None
for i1, i2, i3, i4 in val_loader: #test loader and reconstruct
    shape = i4.shape
    break

# %%
from PIL import Image

def normalize(im):
    max_mrc=np.max(im)
    min_mrc=np.min(im)
    img_original=(255*((im-min_mrc)/(max_mrc-min_mrc))).astype(np.uint8)
    return(img_original)

def preprocess_and_crop(micrograph, crop_size=3840):
    processed_micrograph = simple_micrograph_preprocessing(micrograph)
    if crop_size:
        mic_width, mic_height = processed_micrograph.shape[1], processed_micrograph.shape[0]
        start_x, start_y = (mic_width - crop_size) // 2, (mic_height - crop_size) // 2
        end_x, end_y = start_x + crop_size, start_y + crop_size
        return processed_micrograph[start_y:end_y, start_x:end_x]
    else:
        return processed_micrograph

# %%
from tqdm import tqdm

fnames = []
n = len(full_dataset)
processed_micrographs = np.empty((n, shape[1], shape[2]), dtype=np.float32)

# Use tqdm to wrap your loop for a progress bar
for idx, (test_image, _, grid, _) in tqdm(enumerate(full_dataset), total=n, desc="Processing images"):
    name = full_filenames[idx][:-4]
    fnames.append(name)
    # Determine the directory and load the micrograph
    if os.path.exists(f"{IMAGE_DIR}/test/{name}.npy"):
        micrograph_path = f"{IMAGE_DIR}/test/{name}.npy"
    elif os.path.exists(f"{IMAGE_DIR}/train/{name}.npy"):
        micrograph_path = f"{IMAGE_DIR}/train/{name}.npy"
    else:
        micrograph_path = f"{IMAGE_DIR}/val/{name}.npy"
    micrograph = np.load(micrograph_path)
    processed_micrograph = preprocess_and_crop(micrograph)
    # Place the processed micrograph directly into the preallocated array
    processed_micrographs[idx] = processed_micrograph
# Out:
# Processing images: 100%|██████████| 84/84 [00:36<00:00,  2.31it/s]

# %%
processed_micrographs.shape
# Out:
# (84, 3840, 3840)

# %%
np.save(f"{RESULT_DIR}/processed_micrographs.npy", processed_micrographs)

# %%
processed_micrographs = np.load(f"{RESULT_DIR}/processed_micrographs.npy")

# %%
del model
torch.cuda.empty_cache()

# %%
model = model_post

# %%
RESULT_DIR
# Out:
# '/content/drive/MyDrive/research_xc/results/10017_test/unet_eb5_dice_CDCRF'

# %%
import torch.nn.functional as F

label_images = np.empty((0, shape[1], shape[2]), dtype=np.uint8)

checkpoint_paths = [path for path in os.listdir(RESULT_DIR) if '.pt' in path]
checkpoint_path = checkpoint_paths[-1]
state_dict_path = f"{RESULT_DIR}/{checkpoint_path}"
state_dict = torch.load(state_dict_path, map_location=torch.device(device))
model.load_state_dict(state_dict, strict=False)

model.to(device)
model.eval()

mini_batch_size = 18  # Number of patches to process at once
n = len(full_dataset)
label_images = np.empty((n, shape[1], shape[2]), dtype=np.uint8)  # Preallocated array

# Iterate through the dataset with tqdm for progress tracking
for idx, (test_image, _, grid, _) in tqdm(enumerate(full_dataset), total=n, desc="Processing dataset"):
    # Process in batches
    with torch.no_grad():
        inputs = test_image.to(device)
        num_batches = (inputs.size(0) + mini_batch_size - 1) // mini_batch_size
        patched_outputs = []

        for batch_idx in range(num_batches):
            start_idx = batch_idx * mini_batch_size
            end_idx = min(start_idx + mini_batch_size, inputs.size(0))
            patch_input = inputs[start_idx:end_idx].to(device)
            output = model(patch_input)['out']
            patched_outputs.append(output.cpu())  # Minimize device memory usage

            # Cleanup as soon as not needed
            del patch_input, output
            torch.cuda.empty_cache()

        outputs = torch.cat(patched_outputs)  # Combine outputs
        probabilities = F.softmax(outputs, dim=1)
        class1_probabilities = probabilities[:, 1, :, :]  # Assuming class 1 is the target
        pred_image = reconstruct_patched(class1_probabilities.unsqueeze(1), grid).float()
        output_image = normalize(pred_image.squeeze().numpy())

        # Cleanup large temporary variables
        del patched_outputs, outputs, probabilities, class1_probabilities, pred_image
        torch.cuda.empty_cache()

    # Store the output image directly in the preallocated array
    label_images[idx] = output_image

    if idx % 30 == 0:
        _, ax = plt.subplots(figsize=(12, 12))
        ax.imshow(processed_micrographs[idx], cmap='gray')
        ax.imshow(output_image, cmap='inferno', alpha=0.4)
        plt.show()
    del output_image
    torch.cuda.empty_cache()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
np.save(f"{RESULT_DIR}/label_images.npy", label_images)

# %%
# !cp {RESULT_DIR}/label_images.npy .

# %%
label_images = np.load(f"{RESULT_DIR}/label_images.npy")

# %%
label_images.shape
# Out:
# (84, 3840, 3840)

# %%
# @title  { vertical-output: true, display-mode: "form" }
EMPIAR_ID = 10017 # @param {type:"integer"}
RADIUS = 64 # @param {type:"integer"}
# For 10017
BORDER = 128 # @param {type:"integer"}

# %%
# !cp {RESULT_DIR}/best_config.txt .

# %%
with open("best_config.txt", "r") as f:
    for line in f:
        key, value = line.strip().split(": ", 1)
        if key == "cv_config":
            cv_config = eval(value)
        elif key == "tp_config":
            tp_config = eval(value)
        elif key == "nms_config":
            nms_config = eval(value)

# %% [markdown]
# ### Actual seg

# %%
radius = RADIUS

# %%
from skimage import filters, segmentation, morphology
import skimage as ski
from skimage import img_as_float
from center_finding import normalize, min_rect_circle, eliminate_near
import cv2

# %%
from skimage import img_as_float
from skimage.filters import threshold_local

cv_list = []
for img in label_images:
    output_image = img_as_float(img)
    block_size = int(round(radius * 1.6)) | 1  # Ensure it's an odd number
    local_thresh = filters.threshold_local(output_image, block_size, method='gaussian', offset=0)
    image_seg = output_image > local_thresh
    thresh1 = ski.util.img_as_ubyte(image_seg)

    contr_min = radius*cv_config[1]
    kernel_size = int(radius / cv_config[0])  # Example ratio
    kernel = np.ones((kernel_size, kernel_size), np.uint8)
    thresh1 = cv2.erode(thresh1, kernel, iterations=1)

    contours, hierarchy = cv2.findContours(thresh1,cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)
    cont_array = [c for c in contours]

    # Filter out small/large region and find bounding box with center
    c_ = np.array([cv2.contourArea(contour) for contour in contours])
    aa = (c_>contr_min) & (c_<500000)
    aa = aa.tolist()
    c_full_list = [d for d, keep in zip(cont_array, aa) if keep]
    c_list = (list(map(lambda x: min_rect_circle(x, radius), c_full_list)))
    c_list = [x for x in c_list if x is not None]
    cv_list.append(c_list)
    print(len(c_full_list), len(c_list))
# Out:
# 573 564
# 611 596
# 626 613
# 545 530
# 527 514
# 597 580
# 603 582
# 593 570
# 568 556
# 575 552
# 620 598
# 645 630
# 580 571
# 658 632
# 577 568
# 523 515
# 633 625
# 623 616
# 570 542
# 563 545
# 555 548
# 614 587
# 606 593
# 592 579
# 607 567
# 360 360
# 350 349
# 399 390
# 450 442
# 422 419
# 404 402
# 658 624
# 579 568
# 606 590
# 585 572
# 614 599
# 582 561
# 608 588
# 474 471
# 581 570
# 542 531
# 629 616
# 568 559
# 608 587
# 486 469
# 396 386
# 390 386
# 404 403
# 398 393
# 407 401
# 409 407
# 565 553
# 579 565
# 583 575
# 594 582
# 574 567
# 570 568
# 492 488
# 474 471
# 394 394
# 365 364
# 433 425
# 452 442
# 440 430
# 439 430
# 496 487
# 488 478
# 460 459
# 469 454
# 460 453
# 500 494
# 475 465
# 492 477
# 438 422
# 486 469
# 430 418
# 644 632
# 633 622
# 545 543
# 475 467
# 557 548
# 465 454
# 582 544
# 435 428

# %%
import matplotlib
for idx, (test_image, _, grid, _) in enumerate(full_dataset):
    #if idx == 6:
    #    break
    if idx % 30 == 0:
        label_image = label_images[idx]
        _, ax = plt.subplots(figsize=(12, 12))
        ax.imshow(processed_micrographs[idx], cmap='gray')
        ax.imshow(label_image, cmap='inferno', alpha=0.4)

        for indx in cv_list[idx]:
            x, y = indx
            c = matplotlib.patches.Circle((x, y), radius=RADIUS, fill=False, color='r')
            ax.add_patch(c)
        plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# !pip install starfile -qq
# Out:
# DEPRECATION: Loading egg at /usr/local/lib/python3.11/dist-packages/CRF-0.0.1-py3.11-linux-x86_64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330

# %%
import pandas as pd

for idx, fname in enumerate(fnames):
    # Create the adjusted list of tuples for current index
    adjusted_c_list = [(x + BORDER, y + BORDER) for x, y in cv_list[idx]]

    # Create a temporary DataFrame from the list of tuples
    temp_df = pd.DataFrame(adjusted_c_list, columns=['rlnCoordinateX', 'rlnCoordinateY'])
    temp_df['rlnImageName'] = [f"{i:05d}@{fname}.mrc" for i in range(len(temp_df))]
    temp_df['rlnMicrographName'] = fname + ".mrc"

    # If this is the first DataFrame, initialize df
    if idx == 0:
        df = temp_df
    else:
        # Append the temporary DataFrame to the existing df
        df = pd.concat([df, temp_df], ignore_index=True)

# %%
df
# Out:
#        rlnCoordinateX  rlnCoordinateY                            rlnImageName  \
# 0                3302            3938  00000@Falcon_2012_06_12-14_33_35_0.mrc
# 1                1044            3937  00001@Falcon_2012_06_12-14_33_35_0.mrc
# 2                1857            3931  00002@Falcon_2012_06_12-14_33_35_0.mrc
# 3                 574            3927  00003@Falcon_2012_06_12-14_33_35_0.mrc
# 4                3475            3910  00004@Falcon_2012_06_12-14_33_35_0.mrc
# ...               ...             ...                                     ...
# 43179             296             230  00423@Falcon_2012_06_13-03_06_44_0.mrc
# 43180            1389             161  00424@Falcon_2012_06_13-03_06_44_0.mrc
# 43181             907             167  00425@Falcon_2012_06_13-03_06_44_0.mrc
# 43182            1258             174  00426@Falcon_2012_06_13-03_06_44_0.mrc
# 43183            3116             166  00427@Falcon_2012_06_13-03_06_44_0.mrc
#
#                       rlnMicrographName
# 0      Falcon_2012_06_12-14_33_35_0.mrc
# 1      Falcon_2012_06_12-14_33_35_0.mrc
# 2      Falcon_2012_06_12-14_33_35_0.mrc
# 3      Falcon_2012_06_12-14_33_35_0.mrc
# 4      Falcon_2012_06_12-14_33_35_0.mrc
# ...                                 ...
# 43179  Falcon_2012_06_13-03_06_44_0.mrc
# 43180  Falcon_2012_06_13-03_06_44_0.mrc
# 43181  Falcon_2012_06_13-03_06_44_0.mrc
# 43182  Falcon_2012_06_13-03_06_44_0.mrc
# 43183  Falcon_2012_06_13-03_06_44_0.mrc
#
# [43184 rows x 4 columns]

# %%
import starfile
starfile.write(df, f'{RESULT_DIR}
#         [3465.14235508, 3438.85655712],
#         [3661.96727798, 3504.94280571],
#         [2097.93323805, 3521.72151782],
#         [2648.433055  , 3523.20891777],
#         [3283.79786581, 3470.73659302],
#         [2834.14518421, 3500.34234642],
#         [3006.81192058, 3503.99323598],
#         [2508.69910471, 3576.30159595],
#         [2257.57542534, 3544.18936116],
#         [3189.42651826, 3534.74743214],
#         [1678.16837029, 3580.42564344],
#         [1879.37874723, 3560.47300454],
#         [2390.03395896, 3589.59797724],
#         [2597.84808314, 3631.86363524],
#         [3539.29108526, 3630.71422693],
#         [2872.16350984, 3614.01808252],
#         [3226.08168571, 3640.65991654],
#         [3370.81670136, 3615.41226889],
#         [1777.73621302, 3656.10422878],
#         [2194.21761824, 3712.90933912],
#         [2547.21446911, 3673.89770739],
#         [2054.29463528, 3689.84258722],
#         [2914.52230747, 3752.20808942],
#         [3651.80771019, 3704.28088446],
#         [3175.08792222, 3748.44220937],
#         [2705.60956146, 3735.58473844],
#         [2531.23713144, 3790.43794481]])]

# %%
tp_config
# Out:
# (0.25, 0.4)

# %%
import trackpy as tp

# %%
TrackParticleSize = RADIUS*2-1
curr_adpmass = 0
sep = round(TrackParticleSize*tp_config[1])
scale = tp_config[0]  # Scale factor (0.5 means reducing the size to half)

# %%
tp_list = []
for img in label_images:
    output_image = img
    small_image = cv2.resize(output_image, None, fx=scale, fy=scale, interpolation=cv2.INTER_AREA)
    # Adjust parameters based on the scale
    small_sep = int(sep * scale)
    small_diameter = int(TrackParticleSize * scale)
    if small_diameter % 2 == 0:
        small_diameter += 1
    coorTrack = tp.locate(small_image, diameter=small_diameter, minmass=curr_adpmass, separation=small_sep)
    #coorTrack.loc[:,'prob']=[output_image[getattr(coor,'y'),getattr(coor,'x')] for coor in np.floor(coorTrack[['x','y']]).astype('int').itertuples()]
    coorTrack['x'] *= (1/scale)
    coorTrack['y'] *= (1/scale)
    coords = coorTrack[['x', 'y']].values
    tp_list.append(coords)
    print(len(coords))
# Out:
# 576
# 626
# 615
# 541
# 540
# 647
# 607
# 627
# 573
# 598
# 636
# 631
# 564
# 674
# 584
# 516
# 604
# 601
# 624
# 603
# 540
# 635
# 595
# 589
# 642
# 379
# 358
# 411
# 441
# 413
# 412
# 697
# 599
# 614
# 594
# 632
# 610
# 610
# 473
# 584
# 546
# 623
# 556
# 625
# 505
# 394
# 394
# 387
# 398
# 422
# 412
# 561
# 573
# 576
# 597
# 545
# 580
# 490
# 471
# 419
# 391
# 440
# 471
# 444
# 463
# 506
# 491
# 454
# 476
# 473
# 507
# 465
# 497
# 470
# 480
# 438
# 635
# 638
# 546
# 494
# 568
# 469
# 604
# 449

# %%
import matplotlib
for idx, (test_image, _, grid, _) in enumerate(full_dataset):
    # if idx == 6:
    #     break
    if idx % 30 == 0:
        label_image = label_images[idx]
        _, ax = plt.subplots(figsize=(12, 12))
        ax.imshow(processed_micrographs[idx], cmap='gray')
        ax.imshow(label_image, cmap='inferno', alpha=0.4)

        for indx in tp_list[idx]:
            x, y = indx
            c = matplotlib.patches.Circle((x, y), radius=RADIUS, fill=False, color='r')
            ax.add_patch(c)
        plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
import pandas as pd

for idx, fname in enumerate(fnames):
    # Create the adjusted list of tuples for current index
    adjusted_c_list = [(x + BORDER, y + BORDER) for x, y in tp_list[idx]]

    # Create a temporary DataFrame from the list of tuples
    temp_df = pd.DataFrame(adjusted_c_list, columns=['rlnCoordinateX', 'rlnCoordinateY'])
    temp_df['rlnImageName'] = [f"{i:05d}@{fname}.mrc" for i in range(len(temp_df))]
    temp_df['rlnMicrographName'] = fname + ".mrc"

    # If this is the first DataFrame, initialize df
    if idx == 0:
        df = temp_df
    else:
        # Append the temporary DataFrame to the existing df
        df = pd.concat([df, temp_df], ignore_index=True)

# %%
df
# Out:
#        rlnCoordinateX  rlnCoordinateY                            rlnImageName  \
# 0         1037.058449      207.953393  00000@Falcon_2012_06_12-14_33_35_0.mrc
# 1         1311.594536      209.239537  00001@Falcon_2012_06_12-14_33_35_0.mrc
# 2          448.078618      243.933158  00002@Falcon_2012_06_12-14_33_35_0.mrc
# 3          696.817166      182.958715  00003@Falcon_2012_06_12-14_33_35_0.mrc
# 4         1452.810437      222.935349  00004@Falcon_2012_06_12-14_33_35_0.mrc
# ...               ...             ...                                     ...
# 44753     3042.522307     3880.208089  00444@Falcon_2012_06_13-03_06_44_0.mrc
# 44754     3779.807710     3832.280884  00445@Falcon_2012_06_13-03_06_44_0.mrc
# 44755     3303.087922     3876.442209  00446@Falcon_2012_06_13-03_06_44_0.mrc
# 44756     2833.609561     3863.584738  00447@Falcon_2012_06_13-03_06_44_0.mrc
# 44757     2659.237131     3918.437945  00448@Falcon_2012_06_13-03_06_44_0.mrc
#
#                       rlnMicrographName
# 0      Falcon_2012_06_12-14_33_35_0.mrc
# 1      Falcon_2012_06_12-14_33_35_0.mrc
# 2      Falcon_2012_06_12-14_33_35_0.mrc
# 3      Falcon_2012_06_12-14_33_35_0.mrc
# 4      Falcon_2012_06_12-14_33_35_0.mrc
# ...                                 ...
# 44753  Falcon_2012_06_13-03_06_44_0.mrc
# 44754  Falcon_2012_06_13-03_06_44_0.mrc
# 44755  Falcon_2012_06_13-03_06_44_0.mrc
# 44756  Falcon_2012_06_13-03_06_44_0.mrc
# 44757  Falcon_2012_06_13-03_06_44_0.mrc
#
# [44758 rows x 4 columns]

# %%
import starfile
starfile.write(df, f'{RESULT_DIR}/tp_particles.star')

# %% [markdown]
# ### Nonmax

# %%
import pycuda.driver as drv
from center_finding import cleanCanList, pad_image, reLev, reNorm, scoreGpu, getMax, getMax3, gaussian_kernel_2d_opencv, reshape

# %%
nms_config
# Out:
# (0.5, 0.6)

# %%
#ratio=1
pnum=2000 #initial filtering, larger if candidate is more
pCan=nms_config[0] #the grid size smaller will generate more candidate
overlap=nms_config[1] #allow for overlap
psize=RADIUS*2

# Nor affect too much
level=3
nSep=10
nIter=100

# %%
nms_list = []
for idx, img in enumerate(label_images):
    # if idx == 6:
    #     break
    heatArr=pad_image(img)
    heatArr=reNorm(heatArr, nSep)
    heatArr=reLev(heatArr,level)
    gaus= gaussian_kernel_2d_opencv(kernel_size = psize,sigma = 0)

    # canList,score=scoreGpuLaunch(heatArr,gaus,psize, gsize, nIter, fscore)
    gsize=psize*pCan
    heat=heatArr.astype(np.float32)
    gaus=gaus.astype(np.float32)
    score=np.zeros(heat.shape).astype(np.float32)
    [sizex,sizey]=heat.shape
    sizex = int(sizex)
    sizey = int(sizey)
    psize = int(psize)
    gsize = int(gsize)

    func = scoreGpu

    tx=16
    ty=16
    bx=(sizex-1)//tx+1
    by=(sizey-1)//ty+1
    print('get score gpu',tx, ty, bx, by, gsize, psize)


    func(drv.In(heat), drv.In(gaus), drv.Out(score), np.int32(sizex), np.int32(sizey), np.int32(psize),
        block=(tx, ty, 1), grid=(int(bx), int(by)))

    # # Calculate necessary dimensions and convert all to int
    numx = int((sizex - 1) // gsize + 1)
    numy = int((sizey - 1) // gsize + 1)
    num = numx * numy
    tnum = num * 5

    # # Create the result array
    res = np.zeros(tnum).astype(np.float32)

    # # Block and grid dimensions
    bx = (numx - 1) // tx + 1
    by = (numy - 1) // ty + 1

    # Get the function from the module
    func = getMax

    # Call the function, ensure all parameters are the correct type
    func(drv.In(score), drv.Out(res), np.int32(gsize), np.int32(sizex), np.int32(sizey), np.int32(numx),
        block=(16, 16, 1), grid=(bx, by, 1))

    # Make sure all dimensions and sizes are properly cast to np.int32 to avoid ambiguity
    niter = np.int32(nIter)
    gsize = np.int32(gsize)
    sizex = np.int32(sizex)
    sizey = np.int32(sizey)
    numx = np.int32(numx)
    tnum = np.int32(num)

    print('get Max3', tx, ty, bx, by, niter, 'other : ', gsize, sizex, sizey, numx, tnum)
    func = getMax3
    # Ensuring the correct parameter order and type for the kernel invocation
    func(drv.In(score), drv.InOut(res), gsize, sizex, sizey, numx, tnum, niter,
            block=(16, 16, 1), grid=(bx, by, 1))

    canList=reshape(res,num)

    print('Number of Particles before:', len(canList))
    if(len(canList)>pnum):
        canList=canList[:pnum]


    canList=cleanCanList(canList,overlap,psize)
    #canList=reCan(canList,ratio)
    print('Number of Particles:', len(canList))
    nms_list.append([(r[1],r[0]) for r in canList])
# Out:
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3416
# Number of Particles: 627
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3485
# Number of Particles: 679
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3487
# Number of Particles: 662
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3116
# Number of Particles: 596
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3095
# Number of Particles: 600
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3474
# Number of Particles: 691
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3469
# Number of Particles: 666
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3408
# Number of Particles: 686
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3470
# Number of Particles: 603
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3463
# Number of Particles: 663
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3477
# Number of Particles: 698
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3467
# Number of Particles: 707
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3455
# Number of Particles: 614
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3461
# Number of Particles: 740
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3472
# Number of Particles: 623
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3451
# Number of Particles: 562
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3468
# Number of Particles: 647
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3473
# Number of Particles: 652
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3443
# Number of Particles: 666
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3474
# Number of Particles: 656
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3447
# Number of Particles: 586
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3462
# Number of Particles: 704
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3457
# Number of Particles: 646
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3479
# Number of Particles: 627
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3385
# Number of Particles: 726
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3263
# Number of Particles: 472
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3228
# Number of Particles: 445
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3294
# Number of Particles: 482
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3402
# Number of Particles: 497
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3364
# Number of Particles: 477
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3362
# Number of Particles: 455
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3429
# Number of Particles: 768
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3451
# Number of Particles: 646
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3475
# Number of Particles: 668
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3465
# Number of Particles: 661
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3477
# Number of Particles: 676
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3318
# Number of Particles: 657
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3456
# Number of Particles: 664
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3385
# Number of Particles: 505
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3472
# Number of Particles: 631
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3454
# Number of Particles: 591
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3487
# Number of Particles: 664
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3335
# Number of Particles: 610
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3457
# Number of Particles: 668
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3011
# Number of Particles: 580
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3296
# Number of Particles: 461
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3222
# Number of Particles: 462
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3311
# Number of Particles: 467
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3290
# Number of Particles: 456
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3331
# Number of Particles: 476
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3312
# Number of Particles: 453
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3432
# Number of Particles: 615
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3444
# Number of Particles: 634
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3469
# Number of Particles: 617
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3474
# Number of Particles: 627
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3437
# Number of Particles: 578
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3459
# Number of Particles: 599
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3308
# Number of Particles: 533
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3405
# Number of Particles: 507
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3342
# Number of Particles: 460
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3284
# Number of Particles: 448
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3350
# Number of Particles: 480
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3385
# Number of Particles: 513
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3324
# Number of Particles: 503
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3383
# Number of Particles: 501
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3445
# Number of Particles: 528
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3441
# Number of Particles: 529
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3287
# Number of Particles: 496
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3320
# Number of Particles: 529
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3390
# Number of Particles: 504
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3402
# Number of Particles: 540
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3372
# Number of Particles: 512
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3331
# Number of Particles: 563
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3306
# Number of Particles: 520
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3375
# Number of Particles: 556
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3382
# Number of Particles: 512
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3468
# Number of Particles: 669
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3484
# Number of Particles: 672
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3452
# Number of Particles: 584
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3326
# Number of Particles: 511
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3459
# Number of Particles: 598
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3309
# Number of Particles: 535
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3429
# Number of Particles: 708
# get score gpu 16 16 240 240 64 128
# get Max3 16 16 4 4 100 other :  64 3840 3840 60 3600
# convert
# Number of Particles before: 3084
# Number of Particles: 491

# %%
import matplotlib
for idx, (test_image, _, grid, _) in enumerate(full_dataset):
    # if idx == 6:
    #     break
    if idx % 30 == 0:
    # else:
        label_image = label_images[idx]
        _, ax = plt.subplots(figsize=(12, 12))
        ax.imshow(processed_micrographs[idx], cmap='gray')
        ax.imshow(label_image, cmap='inferno', alpha=0.4)

        for indx in nms_list[idx]:
            x, y = indx
            c = matplotlib.patches.Circle((x, y), radius=RADIUS, fill=False, color='r')
            ax.add_patch(c)
        plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
import pandas as pd

for idx, fname in enumerate(fnames):
    # Create the adjusted list of tuples for current index
    adjusted_c_list = [(x + BORDER, y + BORDER) for x, y in nms_list[idx]]

    # Create a temporary DataFrame from the list of tuples
    temp_df = pd.DataFrame(adjusted_c_list, columns=['rlnCoordinateX', 'rlnCoordinateY'])
    temp_df['rlnImageName'] = [f"{i:05d}@{fname}.mrc" for i in range(len(temp_df))]
    temp_df['rlnMicrographName'] = fname + ".mrc"

    # If this is the first DataFrame, initialize df
    if idx == 0:
        df = temp_df
    else:
        # Append the temporary DataFrame to the existing df
        df = pd.concat([df, temp_df], ignore_index=True)

# %%
df
# Out:
#        rlnCoordinateX  rlnCoordinateY                            rlnImageName  \
# 0              2269.6          1031.0  00000@Falcon_2012_06_12-14_33_35_0.mrc
# 1              2232.8          3361.6  00001@Falcon_2012_06_12-14_33_35_0.mrc
# 2              2201.6           876.8  00002@Falcon_2012_06_12-14_33_35_0.mrc
# 3              2950.2          3084.6  00003@Falcon_2012_06_12-14_33_35_0.mrc
# 4              1365.0          3293.6  00004@Falcon_2012_06_12-14_33_35_0.mrc
# ...               ...             ...                                     ...
# 49086          1468.0          3123.0  00486@Falcon_2012_06_13-03_06_44_0.mrc
# 49087          2853.0          1562.0  00487@Falcon_2012_06_13-03_06_44_0.mrc
# 49088           447.8          1599.0  00488@Falcon_2012_06_13-03_06_44_0.mrc
# 49089          1216.0          2367.0  00489@Falcon_2012_06_13-03_06_44_0.mrc
# 49090          3903.0          3611.0  00490@Falcon_2012_06_13-03_06_44_0.mrc
#
#                       rlnMicrographName
# 0      Falcon_2012_06_12-14_33_35_0.mrc
# 1      Falcon_2012_06_12-14_33_35_0.mrc
# 2      Falcon_2012_06_12-14_33_35_0.mrc
# 3      Falcon_2012_06_12-14_33_35_0.mrc
# 4      Falcon_2012_06_12-14_33_35_0.mrc
# ...                                 ...
# 49086  Falcon_2012_06_13-03_06_44_0.mrc
# 49087  Falcon_2012_06_13-03_06_44_0.mrc
# 49088  Falcon_2012_06_13-03_06_44_0.mrc
# 49089  Falcon_2012_06_13-03_06_44_0.mrc
# 49090  Falcon_2012_06_13-03_06_44_0.mrc
#
# [49091 rows x 4 columns]

# %%
starfile.write(df, f'{RESULT_DIR}/nms_particles.star')
